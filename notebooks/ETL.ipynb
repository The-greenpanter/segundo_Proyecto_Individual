# %% [markdown]
# ### Importamos las librerias necesarias

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ### Convertimos los archivos a Data Frames

# %%
Internet = pd-pd.read_csv()
